# %%
import allpass as a

me = a.allpass(0.625, 0.9)
# Out:
# Setting Delay to 0.625 ms (30 samples @ fs=48000)

# %%
me.delay = 0.0625
# Out:
# Setting Delay to 0.0625 ms (3 samples @ fs=48000)

# %%
from typing import get_type_hints

#my_dict = get_type_hints(me)
attributes = {k: v for k, v in get_type_hints(me).items() if not k.startswith('_')}
attributes
# Out:
# {'delay': float, 'alpha': float, 'fs': int}

# %%
v = attributes['delay']
#v.__name__
getattr(v, '__name__')
# Out:
# 'float'

# %%
get_type_hints(me.process)
# Out:
# {'input': float, 'return': float}

# %%
getattr(me, 'process')
# Out:
# <bound method allpass.process of allpass(delay=0.0625, alpha=0.9, fs=48000, _delay_in_samples=3, _x=array([0., 0., 0.]), _y=array([0., 0., 0.]), _write_index=0, _read_index=1)>

# %%
me.process

# %%
members = {k for k in dir(me) if not k.startswith('_')}
attr_set = set(attributes)
methods = [a for a in members if a not in attr_set]
methods
# Out:
# ['process']

# %%
me2 = a.allpass()
me2
# Out:
# allpass(delay=0.0, alpha=0.0, fs=48000, _delay_in_samples=0, _x=array([0., 0.]), _y=array([0., 0.]), _write_index=0, _read_index=1)
